# %%
# Program to find the student with the highest marks

# Accept number of students
n = int(input("Enter number of students: "))

students = []

# Input tuples (name, marks)
for i in range(n):
    name = input("Enter student name: ")
    marks = int(input("Enter marks: "))
    students.append((name, marks))

# Find student with highest marks
topper = max(students, key=lambda x: x[1])

print("Student with highest marks:", topper[0])
print("Marks:", topper[1])
# Out:
# Student with highest marks: Ritish
# Marks: 96
