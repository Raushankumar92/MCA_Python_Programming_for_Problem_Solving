# %%
import os

# Enter directory path (use "." for current directory)
directory = "."

files_by_extension = {}

# Loop through directory items
for filename in os.listdir(directory):
    if os.path.isfile(os.path.join(directory, filename)):
        # Split extension
        name, ext = os.path.splitext(filename)

        # Handle files without extension
        ext = ext.lower()
        if ext == "":
            ext = "no_extension"

        # Add to dictionary
        files_by_extension.setdefault(ext, []).append(filename)

# Display categorized files
for ext, files in files_by_extension.items():
    print(f"Extension '{ext}':")
    for f in files:
        print("   -", f)
# Out:
# Extension '.ipynb':
#    - practical_01.ipynb
#    - practical_02.ipynb
#    - practical_03.ipynb
#    - practical_04.ipynb
#    - practical_05.ipynb
#    - practical_06.ipynb
#    - practical_07.ipynb
#    - practical_08.ipynb
# Extension '.txt':
#    - sample.txt
