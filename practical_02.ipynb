# %%
choice = input("Enter 'H' for Heads or 'T' for Tails: ").upper()

if choice in ['H', 'T']:
    probability = 1/2
    print(f"Probability of getting {choice} is: {probability}")
else:
    print("Invalid input! Choose H or T.")
# Out:
# Probability of getting H is: 0.5
